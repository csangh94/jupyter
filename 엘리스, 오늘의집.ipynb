# %%
# !pip install JPype1

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from konlpy.tag import Kkma, Hannanum, Twitter

# %%
kkma=Kkma()

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
import numpy as np

# %%
from PIL import Image

# %%
text = open('data/아카이브7-8/07. alice.txt', encoding='utf-8').read()

# %%
alice_mask = np.array(Image.open('data/아카이브7-8/07. alice_mask.png'))

stopwords = set(STOPWORDS)
stopwords.add("said")

# %%
import matplotlib.pyplot as plt
import platform

path = "C:/Windows/Fonts/gulim.ttc"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 
    
# %matplotlib inline

# %%
plt.figure(figsize=(8,8))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask,
              stopwords = stopwords)
wc = wc.generate(text)
wc.words_
# Out:
# {'Alice': 1.0,
#  'said Alice': 0.5888324873096447,
#  'little': 0.4619289340101523,
#  'the Queen': 0.36548223350253806,
#  'one': 0.3197969543147208,
#  'the King': 0.3147208121827411,
#  'thing': 0.29949238578680204,
#  'now': 0.28426395939086296,
#  'Mock Turtle': 0.28426395939086296,
#  'the Mock': 0.26903553299492383,
#  'the Gryphon': 0.26903553299492383,
#  'time': 0.2639593908629442,
#  'quite': 0.2639593908629442,
#  'the Hatter': 0.2639593908629442,
#  'way': 0.25888324873096447,
#  'think': 0.2436548223350254,
#  'went on': 0.2436548223350254,
#  'you know': 0.22842639593908629,
#  'first': 0.2182741116751269,
#  'come': 0.2182741116751269,
#  'voice': 0.2131979695431472,
#  'the Duchess': 0.20812182741116753,
#  'Why': 0.20304568527918782,
#  'never': 0.19289340101522842,
#  "I'm": 0.18781725888324874,
#  'tone': 0.18781725888324874,
#  'came': 0.17766497461928935,
#  'the Dormouse': 0.17766497461928935,
#  'nothing': 0.17258883248730963,
#  'day': 0.16751269035532995,
# ...

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from konlpy.corpus import kobill

# %%
files_ko = kobill.fileids()

# %%
doc_ko= kobill.open('1809890.txt').read()

# %%
doc_ko
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할 \n\n수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인 \n\n자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고 \n\n이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.\n\n  따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려\n\n는 것임(안 제63조제2항제4호).\n\n- 1 -\n\n\x0c법률  제        호\n\n지방공무원법 일부개정법률안\n\n지방공무원법 일부를 다음과 같이 개정한다.\n\n제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자녀를”을 “만 \n\n8세 이하(취학 중인 경우에는 초등학교 2학년 이하를 말한다)의 자녀를”\n\n로 한다.\n\n부      칙\n\n이 법은 공포한 날부터 시행한다.\n\n- 3 -\n\n\x0c신 ·구조문대비표\n\n현      행\n\n개   정   안\n\n제63조(휴직) ① (생  략)\n\n제63조(휴직) ① (현행과 같음)\n\n  ② 공무원이 다음 각 호의 어\n\n  ② -------------------------\n\n느 하나에 해당하는 사유로 휴\n\n----------------------------\n\n직을 원하면 임용권자는 휴직\n\n----------------------------\n\n을 명할 수 있다. 다만, 제4호\n\n-------------.---------------\n\n의 경우에는 대통령령으로 정\n\n-------------------------
# ...

# %%
t=Twitter()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
tokens_ko=t.nouns(doc_ko)

# %%
tokens_ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '의',
#  '안',
#  '번',
#  '호',
#  '발의',
#  '연월일',
#  '발',
#  '의',
#  '자',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '위',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '위',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '만',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '안',
#  '제',
#  '항제',
#  '호',
#  '법률',
#  '제',
#  '호',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '항제',
#  '호',
#  '중',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '만',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
# ...

# %%
ko= nltk.Text(tokens_ko, name='국회 의안 1809호')

# %%
len(ko.tokens)
# Out:
# 735

# %%
len(set(ko.tokens))
# Out:
# 250

# %%
ko.vocab()
# Out:
# FreqDist({'육아휴직': 38, '발생': 19, '만': 18, '이하': 18, '비용': 17, '액': 17, '경우': 16, '세': 16, '자녀': 14, '고용': 14, ...})

# %%
stop_wodrs=['.', '(', ')', ',', "'", '%', '-', 'X', ').', '×','의','자','에','안','번',
                      '호','을','이','다','만','로','가','를']

# %%
ko= [each_word for each_word in ko if each_word not in stop_wodrs]

# %%
ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '발의',
#  '연월일',
#  '발',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '위',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '위',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '제',
#  '항제',
#  '법률',
#  '제',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '항제',
#  '중',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
#  '학년',
#  '이하',
#  '말',
#  '자녀',
#  '부',
#  '칙',
#  '법',
#  '공포',
#  '날',
#  '시행',
#  '신',
#  '구조',
#  '문대비',
#  '표',
#  '현',
# ...

# %%
ko= nltk.Text(ko, name='국회 의안 1809호')

# %%
ko
# Out:
# <Text: 국회 의안 1809호>

# %%
plt.figure(figsize=(12, 6))
ko.plot(50)
plt.show()

# %%
ko.count('초등학교')
# Out:
# 6

# %%
ko.count('공무원')
# Out:
# 10

# %%
ko.concordance('초등학교')
# Out:
# Displaying 6 of 6 matches:
#  안규백 황영철 박영아 김정훈 김학송 의원 인 제안 이유 및 내용 초등학교 저학년 경우 부모 사랑 필요 나이 현재 공무원 자녀 양육 위 육아
#  나이 현재 공무원 자녀 양육 위 육아휴직 수 자녀 나이 세 이하 초등학교 저학년 자녀 위 해당 부모님 일자리 곧 출산 의욕 저하 문제 수
# 일부 개정 법률 지방공무원법 일부 다음 개정 제 항제 중 세 이하 초등학교 취학 전 자녀 세 이하 취학 중인 경우 초등학교 학년 이하 말 자
# 항제 중 세 이하 초등학교 취학 전 자녀 세 이하 취학 중인 경우 초등학교 학년 이하 말 자녀 부 칙 법 공포 날 시행 신 구조 문대비 표
#  수 다만 제 경우 대통령령 정 사정 직 명 생 략 현행 세 이하 초등학교 취 세 이하 취학 중인 경우 학 전 자녀 양육 위 초등학교 학년
#  이하 초등학교 취 세 이하 취학 중인 경우 학 전 자녀 양육 위 초등학교 학년 이하 여 여자 공무원 말 자녀 임신 출산 때 생 략 생 략

# %%
plt.figure(figsize=(12,6))
ko.dispersion_plot(['육아휴직','초등학고','공무원'])

# %%
from fbprophet import Prophet

# %%
today=open('data/오늘의집.txt', encoding='utf-8').read()

# %%
today
# Out:
# '거실에 엔틱한 분위기를 내면서 활용도 높은 쓰임새로 사용중 이네요/현관주변에 소품을 두면 아기자기한 공간이 됩니다ㅎㅎ/주방에 비타민이나 간단하게 사용하는것 두고있어요  ㅇㅅㅇ/\n살면서 처음으로 받아본 꽃다발 선물 무척 기뻐 퇴근길이 더욱 즐거워졌습니다 꽃이 오래 보존될 수 있도록 가이드 받은대로 시원한 물에 담궈 주웠습니다 /여름이 다가와 돗자리를 펼쳤고 앉아서 책을 볼 수 있는 소반을 하나 구매했습니다 레드를 구매하고 싶었으나 품절되어 스카이 블루를 구매했는데 나름 잘 어울리는 것 같아요 어제 받은 꽃병과 매치하니 더 느낌이 나네요 /누워있다가 기타도 쳤다가 책도 보다가 낮잠도 청하는 게으른 여름의 나날들이 행복해집니다 오늘의 집 덕분에 /\n소품/액자/피아노치는 여인/\n카페분위기의 작업공간/베이지화이트원목으로 꾸민 방/\n놀이방/\n/\n/\n 살랑살랑 날_좋은날/\n/\n안방귀퉁이 아이들의 독서공간이에요 벤치스툴 뒤는 불빛책을 보거나 램프를 켜고 혼자서 책 보는 공간으로 꾸몄어요/\n/\n이번에 이케아 쇼파 구입 후 가구배치를 바꿔 봤어요 기존엔 발이 창문을 향하게 침대배치를 했었는데  쇼파가 길어서 튀어나오는 게 보기싫더리구요  투룸이지만 사실 상 작은방은 드레스룸 겸 준비공간이라 침실에서 자주 머물다보니 큰방에 신경을 많이쓰게 되네요 이제 천장 조명을 바꿔 볼까 하는데 예쁜 게 너무 많아서 아직 못정했다는  한쪽벽은 ㄱ자식의 벽으로 되어있어  바테이블과 액자 조화로 가볍게 포인트 줬고 퇴근하고 바테이블에서 가볍게 즐기고 쇼파에 앉아서 플스하면 피로가 싹/직장 동생들 위닝 중/사이드 테이블과 프레임 및 기본 바탕은 블랙으로 뒀어요/\n///\n하루의 시작과 함께 전체적인 스타일을 꾸미는 곳/원목을 좋아하는 사람 중 하나로써 원목의 장점은 사람과 함께 살면서 나이가 들어가는게 느껴진다는 점/\n나의공간 차고를 세탁실으로  /\n거실 TV장으로 삿어요 오랫동안  고민하다 삿어요 역시 너무 맘에들어요 포텐 거실장하나 더 장만했어요 /정면 사진/\n주
# ...

# %%
import matplotlib.font_manager as fm

# %%
import matplotlib.pyplot as plt
import platform

path = "C:/Windows/Fonts/H2GTRE.TTF"
from matplotlib import font_manager, rc
# font_name = font_manager.FontProperties(fname=path).get_name()
# #rc('font', family=font_name)
# rc('font', family='Gothic')|

# %matplotlib inline

# %%
wc2 = WordCloud( background_color='white', font_path=path, max_words=2000, mask=alice_mask,
              stopwords = stop_wodrs, width=800,height=800)
wc2 = wc2.generate_from_frequencies(cnt)
wc2.words_
# Out:
# {'공간': 1.0,
#  '집': 0.9375,
#  '거실': 0.80625,
#  '방': 0.50625,
#  '주방': 0.4875,
#  '테이블': 0.46875,
#  '것': 0.425,
#  '침대': 0.4,
#  '인테리어': 0.4,
#  '침실': 0.3875,
#  '조명': 0.38125,
#  '분위기': 0.375,
#  '느낌': 0.375,
#  '여름': 0.35625,
#  '때': 0.3125,
#  '더': 0.30625,
#  '화이트': 0.30625,
#  '제': 0.3,
#  '시간': 0.29375,
#  '저': 0.2875,
#  '수': 0.275,
#  '소품': 0.26875,
#  '사진': 0.26875,
#  '우리': 0.26875,
#  '베란다': 0.25,
#  '중': 0.24375,
#  '사용': 0.2375,
#  '커튼': 0.23125,
#  '소파': 0.225,
#  '벽': 0.21875,
#  '하나': 0.2125,
#  '오늘': 0.2125,
#  '책': 0.20625,
#  '날': 0.20625,
#  '생각': 0.2,
#  '수납': 0.2,
#  '구매': 0.19375,
#  '아이': 0.19375,
#  '이불': 0.19375,
#  '카페': 0.1875,
#  '그림': 0.1875,
#  '식물': 0.18125,
#  '정리': 0.175,
#  '식탁': 0.175,
#  '홈': 0.175,
#  '쇼파': 0.16875,
#  '꽃': 0.1625,
#  '곳': 0.1625,
#  '해': 0.1625,
#  '내': 0.1625,
#  '고민': 0.15625,
#  '마음': 0.15625,
#  '보고': 0.15625,
#  '이': 0.15625,
#  '가구': 0.15,
#  '나': 0.15,
#  '선반': 0.15,
#  '기분': 0.15,
#  '원목': 0.14375,
#  '침구': 0.14375,
# ...

# %%
plt.figure(figsize=(12,12))
#plt.rc('font', family='NanumGothic')
plt.imshow(wc2)
plt.tight_layout(pad=0)
plt.axis('off')
plt.show()

# %%
token_today=t.nouns(today)

# %%
token_today
# Out:
# ['거실',
#  '엔틱',
#  '분위기',
#  '내면',
#  '활용',
#  '사용',
#  '현관',
#  '주변',
#  '소품',
#  '공간',
#  '주방',
#  '비타민',
#  '사용',
#  '처음',
#  '꽃다발',
#  '선물',
#  '무척',
#  '퇴근길',
#  '더욱',
#  '꽃',
#  '보존',
#  '수',
#  '가이드',
#  '물',
#  '여름',
#  '돗자리',
#  '책',
#  '볼',
#  '수',
#  '소반',
#  '하나',
#  '구매',
#  '레드',
#  '구매',
#  '품절',
#  '스카이',
#  '블루',
#  '구매',
#  '나름',
#  '것',
#  '어제',
#  '꽃',
#  '병과',
#  '매치',
#  '더',
#  '느낌',
#  '기타',
#  '책',
#  '낮잠',
#  '청',
#  '여름',
#  '나날',
#  '오늘',
#  '집',
#  '덕분',
#  '소품',
#  '액자',
#  '피아노',
#  '여인',
#  '카페',
#  '분위기',
#  '작업',
#  '공간',
#  '베이지',
#  '화이트',
#  '원목',
#  '방',
#  '놀이',
#  '방',
#  '날',
#  '날',
#  '안방',
#  '귀퉁이',
#  '아이',
#  '독서',
#  '공간',
#  '벤치',
#  '스툴',
#  '뒤',
#  '불빛',
#  '책',
#  '램프',
#  '혼자',
#  '책',
#  '공간',
#  '이번',
#  '이케아',
#  '쇼파',
#  '구입',
#  '후',
#  '가구',
#  '배치',
#  '기존',
#  '발',
#  '창문',
#  '향',
#  '침대',
#  '배치',
#  '쇼파',
#  '게',
#  '보기',
#  '구',
#  '투룸',
#  '사실',
#  '상',
#  '작은방',
#  '드레스',
#  '룸',
#  '겸',
#  '준비',
#  '공간',
#  '침실',
# ...

# %%
ko2= nltk.Text(token_today, name='오늘의 집')

# %%
len(ko2)
# Out:
# 9404

# %%
len(set(ko2))
# Out:
# 2547

# %%
ko2= [each_word for each_word in ko2 if each_word not in stop_wodrs]

# %%
len(set(ko2))
# Out:
# 2539

# %%
ko2= nltk.Text(token_today, name='오늘의 집')

# %%
ko2
# Out:
# <Text: 오늘의 집>

# %%
ko2.vocab()
# Out:
# FreqDist({'공간': 160, '집': 150, '거실': 129, '방': 81, '주방': 78, '테이블': 75, '것': 68, '침대': 64, '인테리어': 64, '침실': 62, ...})

# %%
plt.figure(figsize=(12, 6))
plt.rc('font', family=font_name)
ko2.plot(50)
plt.show()

# %%
from collections import Counter

# %%
cnt = Counter(token_today)

# %%
cnt
# Out:
# Counter({'거실': 129,
#          '엔틱': 6,
#          '분위기': 60,
#          '내면': 2,
#          '활용': 13,
#          '사용': 38,
#          '현관': 9,
#          '주변': 3,
#          '소품': 43,
#          '공간': 160,
#          '주방': 78,
#          '비타민': 1,
#          '처음': 13,
#          '꽃다발': 2,
#          '선물': 7,
#          '무척': 2,
#          '퇴근길': 1,
#          '더욱': 7,
#          '꽃': 26,
#          '보존': 1,
#          '수': 44,
#          '가이드': 1,
#          '물': 6,
#          '여름': 57,
#          '돗자리': 1,
#          '책': 33,
#          '볼': 7,
#          '소반': 1,
#          '하나': 34,
#          '구매': 31,
#          '레드': 2,
#          '품절': 2,
#          '스카이': 5,
#          '블루': 3,
#          '나름': 7,
#          '것': 68,
#          '어제': 2,
#          '병과': 2,
#          '매치': 3,
#          '더': 49,
#          '느낌': 60,
#          '기타': 2,
#          '낮잠': 4,
#          '청': 1,
#          '나날': 3,
#          '오늘': 34,
#          '집': 150,
#          '덕분': 9,
# ...
