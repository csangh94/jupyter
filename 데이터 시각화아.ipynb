# %%
import numpy as np
import pandas as pd

# %%
seoul_pop = pd.read_excel('data/01. population_in_Seoul.xls', thousands=',',
                                 encoding='euc-kr', header=2)

# %%
seoul_pop=seoul_pop.rename(columns={
    "계":"인구합계",
    "계.1":"한국인계",
    "남자.1":"한국남",
    "여자.1":"한국여",
    "계.2":"외국인계",
    "남자.2":"외국인남",
    "여자.2":"외국인여",
})

# %%
seoul_pop.head()
# Out:
#          기간  자치구         세대        인구합계         남자         여자       한국인계  \
# 0  2017.1/4   합계  4202888.0  10197604.0  5000005.0  5197599.0  9926968.0
# 1  2017.1/4  종로구    72654.0    162820.0    79675.0    83145.0   153589.0
# 2  2017.1/4   중구    59481.0    133240.0    65790.0    67450.0   124312.0
# 3  2017.1/4  용산구   106544.0    244203.0   119132.0   125071.0   229456.0
# 4  2017.1/4  성동구   130868.0    311244.0   153768.0   157476.0   303380.0
#
#          한국남        한국여      외국인계      외국인남      외국인여  세대당인구   65세이상고령자
# 0  4871560.0  5055408.0  270636.0  128445.0  142191.0   2.36  1321458.0
# 1    75611.0    77978.0    9231.0    4064.0    5167.0   2.11    25425.0
# 2    61656.0    62656.0    8928.0    4134.0    4794.0   2.09    20764.0
# 3   111167.0   118289.0   14747.0    7965.0    6782.0   2.15    36231.0
# 4   150076.0   153304.0    7864.0    3692.0    4172.0   2.32    39997.0

# %%
seoul_pop['인구비율']=seoul_pop['인구합계']/10197604.0 *100

# %%
seoul_pop=seoul_pop.drop(0)

# %%
# !pip install googlemaps
import googlemaps
gmaps_key = "AIzaSyCxF9p0e18rdjf1MXyTVK3evaKUeRXmFG0" # 자신의 key를 사용합니다.
gmaps = googlemaps.Client(key=gmaps_key)
seoul_edu=pd.read_csv('data/서울시교육청 교육복지협력기관 현황(20170525)..csv', thousands=',',
                                 encoding='euc-kr')
edu_lat=[]
edu_lng=[]
# 기관의 geocode가 없는 곳 이 있음
for x in seoul_edu['기관명']:
    test=gmaps.geocode(x,language='ko')
    if len(test) == 0:
        print(x)
    else:
        edu_lat.append(test[0].get("geometry")['location']['lat'])
        edu_lng.append(test[0].get("geometry")['location']['lng'])

# %%
seoul_edu['위도']=edu_lat
seoul_edu['경도']=edu_lng

# %%
seoul_edu.head()
# Out:
#    연번 교육지원청 자치구         기관명                  주소                        홈페이지  \
# 0   1  강남서초  강남   대청종합사회복지관  서울 강남구 양재대로 55길 10   http://www.daechung.or.kr
# 1   2  강남서초  강남  태화기독교사회복지관      서울 강남구 광평로 185     http://www.taiwha.or.kr
# 2   3  강남서초  강남      방배유스센터     서울 서초구 방배로5길 11       http://www.bb1318.com
# 3   4  강남서초  서초         손과발     서초구 방배천로 16길 17      http://www.sonbal.net/
# 4   5  강남서초  서초  한국예술심리상담협회    서초구 서초대로 248, 4층  http://www.kapca.net/site/
#
#            전화번호                    사 업 명     분야  비고         위도          경도
# 0   02-459-6332     부모와 자녀가 함께 자라나는 우리마을  지역기반형  지정  37.492615  127.090214
# 1  02-2040-1600               마음에 희망을 품다  지역기반형  자율  37.484741  127.093433
# 2  02-3487-6161    필통사이[Feel이 通하는 우리 사이]  지역기반형  자율  37.478302  126.998975
# 3   02-522-9527                 행복한 성장비전  지역기반형  지정  37.482570  126.983787
# 4   02-584-8730  다세대 가족지원-컬러코칭 프로그램 "예인"  지역기반형  지정  37.491923  127.008650

# %%
import folium

# %%
# !pip install folium

# %%
map_osm = folium.Map(location=[37.554906, 126.9347328], zoom_start=12)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
w1 = list(seoul_edu['위도'])
w2 = list(seoul_edu['경도'])
w3 = list(seoul_edu['기관명'])
len(w1)
# Out:
# 137

# %%
for i in range(0,len(w1)):
    folium.Marker([float(w1[i]), float(w2[i])], popup=w3[i], 
    icon=folium.Icon(icon='cloud')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm.save('index.html')

# %%
map.save('index2.html')

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
geo_path = 'data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, 
                 tiles='Stamen Toner')

map.choropleth(geo_data = geo_str,
               data = seoul_pop,
               columns = ['자치구','인구비율'],
               fill_color = 'PuRd', #PuRd, YlGnBu
               key_on = 'feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_pop
# Out:
#           기간   자치구        세대      인구합계        남자        여자      한국인계  \
# 1   2017.1/4   종로구   72654.0  162820.0   79675.0   83145.0  153589.0
# 2   2017.1/4    중구   59481.0  133240.0   65790.0   67450.0  124312.0
# 3   2017.1/4   용산구  106544.0  244203.0  119132.0  125071.0  229456.0
# 4   2017.1/4   성동구  130868.0  311244.0  153768.0  157476.0  303380.0
# 5   2017.1/4   광진구  158960.0  372164.0  180992.0  191172.0  357211.0
# 6   2017.1/4  동대문구  159839.0  369496.0  182932.0  186564.0  354079.0
# 7   2017.1/4   중랑구  177548.0  414503.0  206102.0  208401.0  409882.0
# 8   2017.1/4   성북구  188512.0  461260.0  224076.0  237184.0  449773.0
# 9   2017.1/4   강북구  141554.0  330192.0  161686.0  168506.0  326686.0
# 10  2017.1/4   도봉구  136613.0  348646.0  171026.0  177620.0  346629.0
# 11  2017.1/4   노원구  219957.0  569384.0  276823.0  292561.0  565565.0
# 12  2017.1/4   은평구  201869.0  494388.0  240220.0  254168.0  489943.0
# 13  2017.1/4  서대문구  137207.0  327163.0  156765.0  170398.0  314982.0
# ...

# %%
seoul_pop=seoul_pop.drop(26)
